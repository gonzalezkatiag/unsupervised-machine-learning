# %%
import pandas as pd

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

# %%
file_path = Path("crypto_data.csv")
crypto_df = pd.read_csv(file_path, index_col = 0)
crypto_df.head(5)
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Only keep cryptocurrencies that are trading
crypto_df = crypto_df.loc[crypto_df['IsTrading'] == True]
crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 365       365Coin          X11       True   PoW/PoS              NaN
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 611     SixEleven      SHA-256       True       PoW              NaN
# 808           808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# SERO   Super Zero       Ethash       True       PoW              NaN
# UOS           UOS      SHA-256       True      DPoI              NaN
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...

# %%
# Delete 'IsTrading' column
crypto_df = crypto_df.drop(columns = 'IsTrading')
crypto_df.head()
# Out:
#       CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       PoW              NaN          611000
# 808        808   SHA-256   PoW/PoS     0.000000e+00               0

# %%
# Removing rows w/ at least 1 null val
crypto_df = crypto_df.dropna()
crypto_df.isnull().sum()
# Out:
# CoinName           0
# Algorithm          0
# ProofType          0
# TotalCoinsMined    0
# TotalCoinSupply    0
# dtype: int64

# %%
# Removing rows w/ cryptocurrencies that have zero coins mined
crypto_df = crypto_df.loc[crypto_df['TotalCoinsMined'] != 0]
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ETH      Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 5 columns]

# %%
# Storing 'CoinName' in its own DF
cryptoname_df = pd.DataFrame(data = crypto_df, columns = ['CoinName'])
cryptoname_df
# Out:
#          CoinName
# 42        42 Coin
# 404       404Coin
# 1337    EliteCoin
# BTC       Bitcoin
# ETH      Ethereum
# ...           ...
# ZEPH       ZEPHYR
# GAP       Gapcoin
# BDX        Beldex
# ZEN       Horizen
# XBC   BitcoinPlus
#
# [533 rows x 1 columns]

# %%
# Droppin 'CoinName' from crypto df
crypto_df = crypto_df.drop(columns = 'CoinName')
crypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42         Scrypt   PoW/PoS     4.199995e+01              42
# 404        Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       SHA-256       PoW     1.792718e+07        21000000
# ETH        Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# GAP        Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX   CryptoNight       PoW     9.802226e+08      1400222610
# ZEN      Equihash       PoW     7.296538e+06        21000000
# XBC        Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 4 columns]

# %%
# Creating dummy variables 
crypto = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])
crypto
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# ...               ...             ...                               ...
# ZEPH     2.000000e+09      2000000000                                 0
# GAP      1.493105e+07       250000000                                 0
# BDX      9.802226e+08      1400222610                                 0
# ZEN      7.296538e+06        21000000                                 0
# XBC      1.283270e+05         1000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %%
# Standardizing data
crypto_scaled = StandardScaler().fit_transform(crypto)
crypto_scaled
# Out:
# array([[-0.11674788, -0.15286468, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.09358885, -0.14499604, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [ 0.52587231,  4.4937636 , -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        ...,
#        [-0.09523411, -0.13215444, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.11658774, -0.15255408, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.11674507, -0.15284989, -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ]])

# %%
# Initialize PCA model & getting 3 principal components
pca = PCA(n_components=0.90)

crypto_pca = pca.fit_transform(crypto_scaled)

# %%
# Transforming PCA data to a DF
crypto_pca_df = pd.DataFrame(data=crypto_pca)
crypto_pca_df.head()
# Out:
#          0         1         2         3             4             5   \
# 0 -0.333759  1.010335 -0.645813  0.009061  5.477533e-14  2.542160e-14
# 1 -0.317078  1.010467 -0.646245  0.009004  5.483060e-14  2.555502e-14
# 2  2.308741  1.636182 -0.741287  0.027146  8.143912e-14  4.461667e-14
# 3 -0.144347 -1.318206  0.216681 -0.007076 -1.981284e-14 -1.076135e-14
# 4 -0.151002 -2.029159  0.440925 -0.010285 -4.318044e-14 -1.994954e-14
#
#              6             7         8         9   ...            65  \
# 0  1.669336e-14 -1.031620e-14  0.000677 -1.313000  ...  1.290547e-15
# 1  1.648297e-14 -9.688574e-15  0.000074 -1.315755  ...  1.100270e-15
# 2  1.776210e-14 -1.832379e-14 -0.049574 -1.540532  ... -3.861549e-14
# 3 -4.714327e-15  5.296434e-15 -0.003528  0.282703  ...  3.013478e-15
# 4 -3.609778e-15  1.210162e-14  0.024224  0.520040  ...  2.396989e-13
#
#              66            67            68            69            70  \
# ...

# %%
# Reducing dimensions of pricipal components w/ t-SNE
tsne = TSNE(learning_rate=30)
tsne_features = tsne.fit_transform(crypto_pca_df)
tsne_features
# Out:
# array([[ 10.702756 , -10.6469965],
#        [  9.448945 , -17.462814 ],
#        [ 21.848557 , -13.9517145],
#        ...,
#        [-22.878187 ,   8.626355 ],
#        [ -9.068207 ,  15.313155 ],
#        [  8.130303 ,   6.8650827]], dtype=float32)

# %%
sns.scatterplot(x=tsne_features.T[0], y=tsne_features.T[1])
plt.title('t-SNE Scatter Plot')
# Out:
# Text(0.5, 1.0, 't-SNE Scatter Plot')

# %%
inertia = []
k = list(range(1, 11))

# Calculating inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(crypto_pca_df)
    inertia.append(km.inertia_)

# Creating the Elbow Curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(list(range(11)))
plt.title('Elbow Curve')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# C:\Users\gonza\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %% [markdown]
# # CONCLUSIONS
#
# Based on the analysis and elbow curve visualization, I would not recommend to cluster the cryptocurrencies as there's no clear k value and therefore no cluster will perform better than the other.
